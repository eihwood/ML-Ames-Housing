# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import boxcox, norm
import re

pd.set_option('display.max_columns', None)
pd.options.display.max_colwidth = 100
plt.style.use('ggplot')
plt.rcParams.update({
    'axes.labelcolor': 'black',
    'axes.titlecolor': 'black',
    'xtick.color': 'black',
    'ytick.color': 'black'
})

# %%
# import raw data
df_raw = pd.read_csv('../data/Ames_HousePrice.csv', index_col=0).reset_index()
df_raw.drop('index', axis=1, inplace=True)

# copy raw data to new df
df = df_raw.copy()

# %%
# function to standardize column names
def camel_to_snake(name):
    name = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', name).lower()

# %%
# rename columns
df.rename(camel_to_snake, axis=1, inplace=True)
df.shape
# Out:
# (2580, 81)

# %%
df.describe()
# Out:
#                 pid  gr_liv_area     sale_price  ms_sub_class  lot_frontage  \
# count  2.580000e+03  2580.000000    2580.000000   2580.000000   2118.000000
# mean   7.148300e+08  1486.039922  178059.623256     57.691860     68.516053
# std    1.886626e+08   488.650181   75031.089374     42.802105     22.835831
# min    5.263011e+08   334.000000   12789.000000     20.000000     21.000000
# 25%    5.313630e+08  1112.000000  129975.000000     20.000000     57.000000
# 50%    5.354546e+08  1436.000000  159900.000000     50.000000     68.000000
# 75%    9.071811e+08  1733.000000  209625.000000     70.000000     80.000000
# max    1.007100e+09  4676.000000  755000.000000    190.000000    313.000000
#
#             lot_area  overall_qual  overall_cond   year_built  year_remod_add  \
# count    2580.000000   2580.000000   2580.000000  2580.000000     2580.000000
# mean    10120.153488      6.046124      5.618605  1970.313953     1983.751938
# std      8126.937892      1.367590      1.122008    29.719705       20.490242
# min      1300.000000      1.000000      1.000000  1872.000000     1950.000000
# 25%      7406.750000      5.000000      5.000000  1953.000000     1965.000000
# 50%      9391.000000      6.000000      5.000000  1972.000000     1992.000000
# 75%     11494.000000      7.000000      6.000000  1999.000000     2003.000000
# max    215245.000000     10.000000      9.000000  2010.000000     2010.000000
#
#        mas_vnr_area  bsmt_fin_sf1  bsmt_fin_sf2  bsmt_unf_sf  total_bsmt_sf  \
# count   2566.000000   2579.000000   2579.000000  2579.000000    2579.000000
# mean      99.308262    444.346258     53.238852   539.101590    1036.686700
# std      175.872330    429.334957    174.423920   425.199639     418.555417
# min        0.000000      0.000000      0.000000     0.000000       0.000000
# 25%        0.000000      0.000000      0.000000   215.000000     792.000000
# 50%        0.000000    384.000000      0.000000   448.000000     979.000000
# 75%      158.000000    732.000000      0.000000   784.000000    1266.500000
# max     1600.000000   2288.000000   1526.000000  2336.000000    3206.000000
#
#         1st_flr_sf   2nd_flr_sf  low_qual_fin_sf  bsmt_full_bath  \
# count  2580.000000  2580.000000      2580.000000     2578.000000
# mean   1144.975194   336.820155         4.244574        0.435221
# std     375.958955   424.072452        44.403603        0.518827
# min     334.000000     0.000000         0.000000        0.000000
# 25%     871.750000     0.000000         0.000000        0.000000
# 50%    1071.000000     0.000000         0.000000        0.000000
# 75%    1364.000000   703.000000         0.000000        1.000000
# max    3820.000000  1872.000000      1064.000000        3.000000
#
#        bsmt_half_bath    full_bath    half_bath  bedroom_abv_gr  \
# count     2578.000000  2580.000000  2580.000000     2580.000000
# mean         0.062064     1.550775     0.378295        2.850388
# std          0.244513     0.545825     0.499237        0.822863
# min          0.000000     0.000000     0.000000        0.000000
# 25%          0.000000     1.000000     0.000000        2.000000
# 50%          0.000000     2.000000     0.000000        3.000000
# 75%          0.000000     2.000000     1.000000        3.000000
# max          2.000000     4.000000     2.000000        6.000000
#
#        kitchen_abv_gr  tot_rms_abv_grd   fireplaces  garage_yr_blt  \
# count      2580.00000      2580.000000  2580.000000    2451.000000
# mean          1.04031         6.387209     0.604264    1976.982048
# std           0.20255         1.535186     0.648604      24.659801
# min           0.00000         2.000000     0.000000    1895.000000
# 25%           1.00000         5.000000     0.000000    1960.000000
# 50%           1.00000         6.000000     1.000000    1978.000000
# 75%           1.00000         7.000000     1.000000    2000.000000
# max           3.00000        13.000000     4.000000    2010.000000
#
#        garage_cars  garage_area  wood_deck_sf  open_porch_sf  enclosed_porch  \
# count  2579.000000  2579.000000   2580.000000    2580.000000     2580.000000
# mean      1.747577   466.842575     95.919767      46.085271       23.214341
# std       0.738678   207.476842    129.052016      66.060664       64.107825
# min       0.000000     0.000000      0.000000       0.000000        0.000000
# 25%       1.000000   318.000000      0.000000       0.000000        0.000000
# 50%       2.000000   474.000000      0.000000      25.500000        0.000000
# 75%       2.000000   576.000000    168.000000      68.000000        0.000000
# max       5.000000  1488.000000   1424.000000     742.000000     1012.000000
#
#        3_ssn_porch  screen_porch    pool_area      misc_val      mo_sold  \
# count  2580.000000   2580.000000  2580.000000   2580.000000  2580.000000
# mean      2.511240     16.200388     1.662016     48.731395     6.150775
# std      25.293935     56.824783    30.339396    498.725058     2.670647
# min       0.000000      0.000000     0.000000      0.000000     1.000000
# 25%       0.000000      0.000000     0.000000      0.000000     4.000000
# 50%       0.000000      0.000000     0.000000      0.000000     6.000000
# 75%       0.000000      0.000000     0.000000      0.000000     8.000000
# max     508.000000    576.000000   800.000000  15500.000000    12.000000
#
#            yr_sold
# count  2580.000000
# mean   2007.838372
# std       1.312333
# min    2006.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2010.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pid              2580 non-null   int64
#  1   gr_liv_area      2580 non-null   int64
#  2   sale_price       2580 non-null   int64
#  3   ms_sub_class     2580 non-null   int64
#  4   ms_zoning        2580 non-null   object
#  5   lot_frontage     2118 non-null   float64
#  6   lot_area         2580 non-null   int64
#  7   street           2580 non-null   object
#  8   alley            168 non-null    object
#  9   lot_shape        2580 non-null   object
#  10  land_contour     2580 non-null   object
#  11  utilities        2580 non-null   object
#  12  lot_config       2580 non-null   object
#  13  land_slope       2580 non-null   object
#  14  neighborhood     2580 non-null   object
#  15  condition1       2580 non-null   object
#  16  condition2       2580 non-null   object
#  17  bldg_type        2580 non-null   object
#  18  house_style      2580 non-null   object
#  19  overall_qual     2580 non-null   int64
#  20  overall_cond     2580 non-null   int64
#  21  year_built       2580 non-null   int64
#  22  year_remod_add   2580 non-null   int64
#  23  roof_style       2580 non-null   object
#  24  roof_matl        2580 non-null   object
#  25  exterior1st      2580 non-null   object
#  26  exterior2nd      2580 non-null   object
#  27  mas_vnr_type     2566 non-null   object
#  28  mas_vnr_area     2566 non-null   float64
#  29  exter_qual       2580 non-null   object
#  30  exter_cond       2580 non-null   object
#  31  foundation       2580 non-null   object
#  32  bsmt_qual        2511 non-null   object
#  33  bsmt_cond        2511 non-null   object
#  34  bsmt_exposure    2509 non-null   object
#  35  bsmt_fin_type1   2511 non-null   object
#  36  bsmt_fin_sf1     2579 non-null   float64
#  37  bsmt_fin_type2   2510 non-null   object
#  38  bsmt_fin_sf2     2579 non-null   float64
#  39  bsmt_unf_sf      2579 non-null   float64
#  40  total_bsmt_sf    2579 non-null   float64
#  41  heating          2580 non-null   object
#  42  heating_qc       2580 non-null   object
#  43  central_air      2580 non-null   object
#  44  electrical       2579 non-null   object
#  45  1st_flr_sf       2580 non-null   int64
#  46  2nd_flr_sf       2580 non-null   int64
#  47  low_qual_fin_sf  2580 non-null   int64
#  48  bsmt_full_bath   2578 non-null   float64
#  49  bsmt_half_bath   2578 non-null   float64
#  50  full_bath        2580 non-null   int64
#  51  half_bath        2580 non-null   int64
#  52  bedroom_abv_gr   2580 non-null   int64
#  53  kitchen_abv_gr   2580 non-null   int64
#  54  kitchen_qual     2580 non-null   object
#  55  tot_rms_abv_grd  2580 non-null   int64
#  56  functional       2580 non-null   object
#  57  fireplaces       2580 non-null   int64
#  58  fireplace_qu     1339 non-null   object
#  59  garage_type      2453 non-null   object
#  60  garage_yr_blt    2451 non-null   float64
#  61  garage_finish    2451 non-null   object
#  62  garage_cars      2579 non-null   float64
#  63  garage_area      2579 non-null   float64
#  64  garage_qual      2451 non-null   object
#  65  garage_cond      2451 non-null   object
#  66  paved_drive      2580 non-null   object
#  67  wood_deck_sf     2580 non-null   int64
#  68  open_porch_sf    2580 non-null   int64
#  69  enclosed_porch   2580 non-null   int64
#  70  3_ssn_porch      2580 non-null   int64
#  71  screen_porch     2580 non-null   int64
#  72  pool_area        2580 non-null   int64
#  73  pool_qc          9 non-null      object
#  74  fence            525 non-null    object
#  75  misc_feature     97 non-null     object
#  76  misc_val         2580 non-null   int64
#  77  mo_sold          2580 non-null   int64
#  78  yr_sold          2580 non-null   int64
#  79  sale_type        2580 non-null   object
#  80  sale_condition   2580 non-null   object
# dtypes: float64(11), int64(27), object(43)
# memory usage: 1.6+ MB

# %%
# variable types
unique = ['pid']

# years/months could be treated as discrete or nominal; depends on the objective;
discrete = ['bsmt_full_bath', 'bsmt_half_bath', 'full_bath', 'half_bath', \
            'bedroom_abv_gr', 'kitchen_abv_gr', 'tot_rms_abv_grd', 'fireplaces', \
            'garage_yr_blt', 'garage_cars', 'mo_sold', 'yr_sold', \
            'year_built', 'year_remod_add']

continuous = ['sale_price', 'lot_frontage', 'lot_area', 'mas_vnr_area', \
              'bsmt_fin_sf1', 'bsmt_fin_sf2', 'bsmt_unf_sf', 'total_bsmt_sf', \
              '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf', 'gr_liv_area', \
              'garage_area', 'wood_deck_sf', 'open_porch_sf', 'enclosed_porch', \
              '3_ssn_porch', 'screen_porch', 'pool_area', 'misc_val']

nominal = ['ms_zoning', 'street', 'alley', 'land_contour', \
           'lot_config', 'neighborhood', 'condition1', 'condition2', \
           'bldg_type', 'house_style', 'roof_style', 'roof_matl', \
           'exterior1st', 'exterior2nd', 'mas_vnr_type', 'foundation', \
           'heating', 'central_air', 'garage_type', 'misc_feature', \
           'sale_type', 'sale_condition', 'ms_sub_class']

ordinal = ['overall_qual', 'lot_shape', 'overall_cond', 'exter_qual', \
           'exter_cond', 'bsmt_qual', 'bsmt_cond', 'bsmt_exposure', \
           'bsmt_fin_type1', 'bsmt_fin_type2', 'heating_qc', 'kitchen_qual', \
           'functional', 'fireplace_qu', 'garage_qual', 'garage_cond', \
           'pool_qc', 'utilities', 'land_slope', 'electrical', \
           'garage_finish', 'paved_drive', 'fence']

# %% [markdown]
# # Log Transformation

# %%
# create new column bc_sale_price
df['log_sale_price'] = np.log(df['sale_price'])

# %%
# plot normal overlay
mean_sp = np.mean(df['sale_price'])
sd_sp = np.std(df['sale_price'])
mean_lsp = np.mean(df['log_sale_price'])
sd_lsp = np.std(df['log_sale_price'])

# %%
x_axis_log = np.arange(10.5,13.5,.01)
y_axis_log = norm.pdf(x_axis_log, mean_lsp, sd_lsp)
x_axis = np.arange(25000,750000,5)
y_axis = norm.pdf(x_axis, mean_sp, sd_sp)

# %%
plt.figure(figsize=(7,7))
sns.histplot(data=df, x='sale_price', stat='probability')
plt.xlabel('Sale Price')
plt.ylabel('Density')
plt.tight_layout()
plt.savefig('hist.png', transparent=True)

# %%
sns.histplot(data=df, x='sale_price', kde=True, stat='density')
sns.lineplot(x=x_axis, y=y_axis, label='Normal Distribution', color='salmon')
plt.legend()
plt.xlabel('Sale Price')
plt.yticks(ticks = [0.000, 2e-6, 4e-6, 6e-6, 8e-6], labels = [0.0,0.2, 0.4, 0.6, 0.8])
plt.tight_layout()
plt.savefig('hist_bf.png', transparent=True)
plt.show()

# %%
sns.histplot(data=df, x='log_sale_price', kde=True, stat='density')
sns.lineplot(x=x_axis_log, y=y_axis_log, label='Normal Distribution', color='salmon')
plt.legend()
plt.xlabel('Log Sale Price')
plt.tight_layout()
plt.savefig('hist_after.png', transparent=True)
plt.show()

# %%
plot = sns.jointplot(data=df, x=df.overall_qual, height=8, y='log_sale_price', ratio=4, kind='reg', color='#EEFE41', ylim=(10.25,13.9))
plot.set_axis_labels('Overall Quality', 'Log Sale Price')
plt.tight_layout()
plt.savefig('log_joint_qual.png', transparent=True)

# %%
plot = sns.jointplot(data=df, x=np.log(df.gr_liv_area), height=8, y='log_sale_price', ratio=4, kind='reg', color='#EEFE41', ylim=(10.25,13.9))
plot.set_axis_labels('Above Ground Living Area (sqft)', 'Log Sale Price')
plt.tight_layout()
plt.savefig('log_joint_sqft.png', transparent=True)

# %% [markdown]
# # Data Cleanup

# %%
# remove duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Fill NaNs

# %%
null_pct = round(df.isnull().mean()*100,4)
nulls_ranked = null_pct[null_pct>0].sort_values()

null_df = pd.DataFrame({'Feature':nulls_ranked.index, '% NaN':nulls_ranked.values})
null_df
labels_ = [f'{x}%' for x in null_df['% NaN'].tolist()]
null_df
# Out:
#            Feature    % NaN
# 0       electrical   0.0388
# 1      garage_area   0.0388
# 2    total_bsmt_sf   0.0388
# 3      bsmt_unf_sf   0.0388
# 4     bsmt_fin_sf1   0.0388
# 5     bsmt_fin_sf2   0.0388
# 6      garage_cars   0.0388
# 7   bsmt_full_bath   0.0775
# 8   bsmt_half_bath   0.0775
# 9     mas_vnr_area   0.5428
# 10    mas_vnr_type   0.5428
# 11  bsmt_fin_type1   2.6755
# 12       bsmt_qual   2.6755
# 13       bsmt_cond   2.6755
# 14  bsmt_fin_type2   2.7142
# 15   bsmt_exposure   2.7530
# 16     garage_type   4.9244
# 17   garage_finish   5.0019
# 18     garage_qual   5.0019
# 19     garage_cond   5.0019
# 20   garage_yr_blt   5.0019
# 21    lot_frontage  17.9139
# 22    fireplace_qu  48.1194
# 23           fence  79.6433
# 24           alley  93.4858
# 25    misc_feature  96.2389
# 26         pool_qc  99.6510

# %%
fig, ax = plt.subplots(figsize=(5,5))
bars = ax.barh(null_df['Feature'].tolist()[9:], null_df['% NaN'].tolist()[9:], color='#EEFE41', **{'alpha':0.8})
ax.bar_label(bars, labels=labels_[9:], label_type='center', padding=10)
ax.set_xlim(0,115)
ax.set_xticks([0,20,40,60,80,100])
ax.set_xlabel('% NaN')
ax.set_ylabel('Features')
plt.tight_layout()
plt.savefig('null_bar.png', transparent=True)
plt.show()

# %%
# function to find and list null values
def null_finder(df):
    keys = []
    na_counts = []
    values = []
    for col in df:
        na_count = df[col].isna().sum()
        if na_count > 0:
            keys.append(col)
            na_counts.append(na_count)
            values.append(df[col].unique().tolist())
        else:
            continue
    return pd.DataFrame({'feature':keys, 'null_count':na_counts, 'values':values}).sort_values(by='null_count', ascending=False)

# %%
null_finder(df)
# Out:
#            feature  null_count  \
# 24         pool_qc        2570
# 26    misc_feature        2482
# 1            alley        2411
# 25           fence        2054
# 16    fireplace_qu        1241
# 0     lot_frontage         462
# 23     garage_cond         129
# 22     garage_qual         129
# 19   garage_finish         129
# 18   garage_yr_blt         129
# 17     garage_type         127
# 6    bsmt_exposure          71
# 9   bsmt_fin_type2          70
# 7   bsmt_fin_type1          69
# 4        bsmt_qual          69
# 5        bsmt_cond          69
# 3     mas_vnr_area          14
# 2     mas_vnr_type          14
# 15  bsmt_half_bath           2
# 14  bsmt_full_bath           2
# 12   total_bsmt_sf           1
# 11     bsmt_unf_sf           1
# 20     garage_cars           1
# 21     garage_area           1
# 10    bsmt_fin_sf2           1
# 8     bsmt_fin_sf1           1
# 13      electrical           1
#
#                                                                                                  values
# 24                                                                                [nan, Ex, Gd, Fa, TA]
# 26                                                                        [nan, Shed, Othr, Gar2, TenC]
# 1                                                                                     [nan, Pave, Grvl]
# 25                                                                      [nan, GdWo, MnPrv, GdPrv, MnWw]
# 16                                                                            [Gd, nan, Ex, TA, Fa, Po]
# 0   [nan, 42.0, 60.0, 80.0, 70.0, 64.0, 53.0, 74.0, 35.0, 48.0, 63.0, 62.0, 50.0, 68.0, 45.0, 65.0, ...
# 23                                                                            [TA, Po, nan, Fa, Gd, Ex]
# 22                                                                            [TA, nan, Fa, Gd, Po, Ex]
# 19                                                                                 [Unf, Fin, RFn, nan]
# 18  [1939.0, 1984.0, 1930.0, 1940.0, 2001.0, 2003.0, 1974.0, 2007.0, 2005.0, 1993.0, 1920.0, 1963.0,...
# 17                                             [Detchd, Attchd, BuiltIn, Basment, nan, 2Types, CarPort]
# 6                                                                                 [No, Mn, nan, Gd, Av]
# 9                                                                   [Unf, ALQ, nan, GLQ, BLQ, LwQ, Rec]
# 7                                                                   [Rec, GLQ, ALQ, Unf, nan, BLQ, LwQ]
# 4                                                                             [TA, Gd, Fa, nan, Ex, Po]
# 5                                                                             [TA, nan, Fa, Gd, Ex, Po]
# 3   [0.0, 149.0, 500.0, 20.0, 76.0, 196.0, 247.0, 113.0, 120.0, 80.0, 28.0, 170.0, 492.0, 44.0, 216....
# 2                                                                   [None, BrkFace, Stone, BrkCmn, nan]
# 15                                                                                 [0.0, 1.0, 2.0, nan]
# 14                                                                            [1.0, 0.0, 2.0, 3.0, nan]
# 12  [856.0, 1049.0, 837.0, 405.0, 810.0, 0.0, 936.0, 1146.0, 864.0, 547.0, 1342.0, 624.0, 861.0, 139...
# 11  [618.0, 104.0, 100.0, 405.0, 167.0, 0.0, 936.0, 1146.0, 217.0, 80.0, 1318.0, 166.0, 861.0, 785.0...
# 20                                                                  [2.0, 1.0, 0.0, 4.0, 3.0, nan, 5.0]
# 21  [399.0, 266.0, 216.0, 281.0, 528.0, 672.0, 576.0, 428.0, 484.0, 525.0, 550.0, 288.0, 514.0, 532....
# 10  [0.0, 393.0, 270.0, 169.0, 32.0, 532.0, 811.0, 216.0, 712.0, 488.0, 281.0, 480.0, 72.0, 912.0, 4...
# 8   [238.0, 552.0, 737.0, 0.0, 643.0, 647.0, 467.0, 24.0, 458.0, 609.0, 810.0, 602.0, 925.0, 41.0, 1...
# 13                                                                    [SBrkr, FuseF, FuseA, FuseP, nan]

# %% [markdown]
# ### pool_qc
# Pool Quality
# - Ex - Excellent
# - Gd - Good
# - TA - Average/Typical
# - Fa - Fair
# - NA - No Pool

# %%
# cross-reference with Pool Area
df[df['pool_qc'].isna()]['pool_area'].value_counts(0)
# Out:
# 0    2570
# Name: pool_area, dtype: int64

# %%
# 0 pool area for all empty values, populate with NA
df['pool_qc'].fillna('NA', inplace=True)

# %% [markdown]
# ### misc_feature
# Miscellaneous feature not covered in other categories

# %%
df.misc_feature.value_counts()
# Out:
# Shed    88
# Gar2     5
# Othr     3
# TenC     1
# Name: misc_feature, dtype: int64

# %%
# fill empties with NA
df['misc_feature'].fillna('NA', inplace=True)

# %% [markdown]
# ### alley
# Type of alley access to property

# %%
df.alley.value_counts()
# Out:
# Grvl    105
# Pave     63
# Name: alley, dtype: int64

# %%
# fill empties with NA
df['alley'].fillna('NA', inplace=True)

# %% [markdown]
# ### fence
# Fence quality

# %%
df.fence.value_counts()
# Out:
# MnPrv    301
# GdPrv    111
# GdWo     103
# MnWw      10
# Name: fence, dtype: int64

# %%
# fill empties with NA
df['fence'].fillna('NA', inplace=True)

# %% [markdown]
# ### fireplace_qu
# Fireplace quality

# %%
# cross-reference with Number of fireplaces
df[df['fireplace_qu'].isna()]['fireplaces'].value_counts(0)
# Out:
# 0    1241
# Name: fireplaces, dtype: int64

# %%
# 0 fireplaces for all empty values, populate with NA
df['fireplace_qu'].fillna('NA', inplace=True)

# %% [markdown]
# ### lot_frontage
# Linear feet of street connected to property

# %%
# examine relationship between lot_frontage & bc_sale_price
print(f'r-value: {df.lot_frontage.corr(df.log_sale_price)}')
sns.scatterplot(data=df, x='lot_frontage', y='log_sale_price')
plt.show()
# Out:
# r-value: 0.35745794151903537

# %%
# look at relationship with lot config
sns.boxplot(data=df, x='lot_config', y='lot_frontage')
plt.show()

# %%
# view value distribution across lot config categories
print(df.lot_config.value_counts())
print(df[df['lot_frontage'].isna()]['lot_config'].value_counts(0))
# Out:
# Inside     1885
# Corner      439
# CulDSac     164
# FR2          78
# FR3          13
# Name: lot_config, dtype: int64
# Inside     261
# Corner      95
# CulDSac     83
# FR2         20
# FR3          3
# Name: lot_config, dtype: int64

# %%
# find median for each lot config
df.groupby('lot_config')['lot_frontage'].agg('median')
# Out:
# lot_config
# Corner     80.0
# CulDSac    49.0
# FR2        60.0
# FR3        66.0
# Inside     65.0
# Name: lot_frontage, dtype: float64

# %%
# populate NaNs with median by lot config (resistant to outliers)
df.loc[(df.lot_frontage.isna()) & (df.lot_config == 'Corner'), 'lot_frontage'] = 80
df.loc[(df.lot_frontage.isna()) & (df.lot_config == 'CulDSac'), 'lot_frontage'] = 49
df.loc[(df.lot_frontage.isna()) & (df.lot_config == 'FR2'), 'lot_frontage'] = 60
df.loc[(df.lot_frontage.isna()) & (df.lot_config == 'FR3'), 'lot_frontage'] = 66
df.loc[(df.lot_frontage.isna()) & (df.lot_config == 'Inside'), 'lot_frontage'] = 65

# %% [markdown]
# ### Garage Features
# - garage_type
#  - Garage location
# - garage_cars
#  - size of garage in car capacity
# - garage_area
#  - size of garage in sq ft
# - garage_qual
#  - Garage Quality
# - garage_cond
#  - Garage Condition
# - garage_finish
#  - Interior finish of the garage

# %%
# cross reference garage type with garage area
df[df['garage_type'].isna()]['garage_area'].value_counts(0)
# Out:
# 0.0    127
# Name: garage_area, dtype: int64

# %%
# populate NaNs with 'NA' for no garage
df['garage_type'].fillna('NA', inplace=True)

# %% [markdown]
# Where garage_type = 'NA'; populate remaining columns with appropriate values (NA)

# %%
# set garage_qual and garage_cond and garage_finish to NA
df.loc[(df.garage_qual.isna()) & (df.garage_type == 'NA'), 'garage_qual'] = 'NA'
df.loc[(df.garage_cond.isna()) & (df.garage_type == 'NA'), 'garage_cond'] = 'NA'
df.loc[(df.garage_finish.isna()) & (df.garage_type == 'NA'), 'garage_finish'] = 'NA'

# %% [markdown]
# Where there is a garage, but no quality, condition, or finisih; fill in with the mode for categorical and median for numeric

# %%
# categorical
df['garage_qual'].fillna(df.garage_qual.mode()[0], inplace=True)
df['garage_cond'].fillna(df.garage_cond.mode()[0], inplace=True)
df['garage_finish'].fillna(df.garage_finish.mode()[0], inplace=True)

# numeric
df['garage_cars'].fillna(df.garage_cars.median(), inplace=True)
df['garage_area'].fillna(df.loc[df.garage_cars == df.garage_cars.median()]['garage_area'].median(), inplace=True)

# %% [markdown]
# ### Basement Features
# - bsmt_qual - Evaluates the height of the basement
# - bsmt_cond - Evaluates the general condition of the basement
# - bsmt_exposure - refers to walkout or garden level walls
# - bsmt_fin_type1 - Rating of basement finished area
# - bsmt_fin_type2 - Rating of basement finished area (if multiple)
# - bsmt_fin_sf1 - Type 1 finished sqft
# - bsmt_fin_sf2 - Type 2 finished sqft
# - bsmt_unf_sf - Unfinished square feet of basement area
# - total_bsmt_sf - Total square feet of basement area
# - bsmt_full_bath - Basement full bathrooms
# - bsmt_half_bathrooms - Basement half bathrooms

# %%
# cross reference bsmt_qual with total_bsmt_sf
df[df['bsmt_qual'].isna()]['total_bsmt_sf'].value_counts(0)
# Out:
# 0.0    68
# Name: total_bsmt_sf, dtype: int64

# %%
# all are 0, populate NaNs with 'NA' for no basement
df['bsmt_qual'].fillna('NA', inplace=True)

# %%
# cross reference bsmt_cond with basement_qual
df[df['bsmt_cond'].isna()]['bsmt_qual'].value_counts(0)
# Out:
# NA    69
# Name: bsmt_qual, dtype: int64

# %%
# all are NA, populate NaNs with 'NA' for no basement
df['bsmt_cond'].fillna('NA', inplace=True)

# %%
# cross reference bsmt_fin_type1 with basement_qual
df[df['bsmt_fin_type1'].isna()]['bsmt_qual'].value_counts(0)
# Out:
# NA    69
# Name: bsmt_qual, dtype: int64

# %%
# all are NA, populate NaNs with 'NA' for no basement
df['bsmt_fin_type1'].fillna('NA', inplace=True)

# %%
# cross reference bsmt_fin_type2 with basement_qual
df[df['bsmt_fin_type2'].isna()]['bsmt_qual'].value_counts(0)
# Out:
# NA    69
# Gd     1
# Name: bsmt_qual, dtype: int64

# %%
# fill with NA where 'bsmt_qual' = NA
df.loc[(df.bsmt_fin_type2.isna()) & (df.bsmt_qual == 'NA'), 'bsmt_fin_type2'] = 'NA'

# fill remaining with mode
df['bsmt_fin_type2'].fillna(df.bsmt_fin_type2.mode()[0], inplace=True)

# %%
# look at Bsmt full/half bath observations
df.loc[(df.bsmt_full_bath.isna())|(df.bsmt_half_bath.isna())]
# Out:
#             pid  gr_liv_area  sale_price  ms_sub_class ms_zoning  \
# 912   903230120          896       79000            20        RM
# 2308  908154080         3820      284700            20        RL
#
#       lot_frontage  lot_area street alley lot_shape land_contour utilities  \
# 912           99.0      5940   Pave    NA       IR1          Lvl    AllPub
# 2308         123.0     47007   Pave    NA       IR1          Lvl    AllPub
#
#      lot_config land_slope neighborhood condition1 condition2 bldg_type  \
# 912         FR3        Gtl      BrkSide      Feedr       Norm      1Fam
# 2308     Inside        Gtl      Edwards       Norm       Norm      1Fam
#
#      house_style  overall_qual  overall_cond  year_built  year_remod_add  \
# 912       1Story             4             7        1946            1950
# 2308      1Story             5             7        1959            1996
#
#      roof_style roof_matl exterior1st exterior2nd mas_vnr_type  mas_vnr_area  \
# 912       Gable   CompShg     MetalSd      CBlock         None           0.0
# 2308      Gable   CompShg     Plywood     Plywood         None           0.0
#
#      exter_qual exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure  \
# 912          TA         TA      PConc        NA        NA           NaN
# 2308         TA         TA       Slab        NA        NA           NaN
#
#      bsmt_fin_type1  bsmt_fin_sf1 bsmt_fin_type2  bsmt_fin_sf2  bsmt_unf_sf  \
# 912              NA           NaN             NA           NaN          NaN
# 2308             NA           0.0             NA           0.0          0.0
#
#       total_bsmt_sf heating heating_qc central_air electrical  1st_flr_sf  \
# 912             NaN    GasA         TA           Y      FuseA         896
# 2308            0.0    GasA         TA           Y      SBrkr        3820
#
#       2nd_flr_sf  low_qual_fin_sf  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 912            0                0             NaN             NaN          1
# 2308           0                0             NaN             NaN          3
#
#       half_bath  bedroom_abv_gr  kitchen_abv_gr kitchen_qual  tot_rms_abv_grd  \
# 912           0               2               1           TA                4
# 2308          1               5               1           Ex               11
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 912         Typ           0           NA      Detchd         1946.0
# 2308        Typ           2           Gd      Attchd         1959.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 912            Unf          1.0        280.0          TA          TA
# 2308           Unf          2.0        624.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3_ssn_porch  \
# 912            Y             0              0               0            0
# 2308           Y             0            372               0            0
#
#       screen_porch  pool_area pool_qc  fence misc_feature  misc_val  mo_sold  \
# 912              0          0      NA  MnPrv           NA         0        4
# 2308             0          0      NA     NA           NA         0        7
#
#       yr_sold sale_type sale_condition  log_sale_price
# 912      2008     ConLD        Abnorml       11.277203
# 2308     2008       WD          Normal       12.559191

# %%
# no basement for both records, populate baths with 0
df['bsmt_full_bath'].fillna(0, inplace=True)
df['bsmt_half_bath'].fillna(0, inplace=True)

# %%
# look at total_bsmt_sf records
df.loc[(df.total_bsmt_sf.isna())]
# Out:
#            pid  gr_liv_area  sale_price  ms_sub_class ms_zoning  lot_frontage  \
# 912  903230120          896       79000            20        RM          99.0
#
#      lot_area street alley lot_shape land_contour utilities lot_config  \
# 912      5940   Pave    NA       IR1          Lvl    AllPub        FR3
#
#     land_slope neighborhood condition1 condition2 bldg_type house_style  \
# 912        Gtl      BrkSide      Feedr       Norm      1Fam      1Story
#
#      overall_qual  overall_cond  year_built  year_remod_add roof_style  \
# 912             4             7        1946            1950      Gable
#
#     roof_matl exterior1st exterior2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 912   CompShg     MetalSd      CBlock         None           0.0         TA
#
#     exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmt_fin_type1  \
# 912         TA      PConc        NA        NA           NaN             NA
#
#      bsmt_fin_sf1 bsmt_fin_type2  bsmt_fin_sf2  bsmt_unf_sf  total_bsmt_sf  \
# 912           NaN             NA           NaN          NaN            NaN
#
#     heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 912    GasA         TA           Y      FuseA         896           0
#
#      low_qual_fin_sf  bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  \
# 912                0             0.0             0.0          1          0
#
#      bedroom_abv_gr  kitchen_abv_gr kitchen_qual  tot_rms_abv_grd functional  \
# 912               2               1           TA                4        Typ
#
#      fireplaces fireplace_qu garage_type  garage_yr_blt garage_finish  \
# 912           0           NA      Detchd         1946.0           Unf
#
#      garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 912          1.0        280.0          TA          TA           Y
#
#      wood_deck_sf  open_porch_sf  enclosed_porch  3_ssn_porch  screen_porch  \
# 912             0              0               0            0             0
#
#      pool_area pool_qc  fence misc_feature  misc_val  mo_sold  yr_sold  \
# 912          0      NA  MnPrv           NA         0        4     2008
#
#     sale_type sale_condition  log_sale_price
# 912     ConLD        Abnorml       11.277203

# %%
# no basement, populate all basement SF features with 0
df['total_bsmt_sf'].fillna(0, inplace=True)
df['bsmt_unf_sf'].fillna(0, inplace=True)
df['bsmt_fin_sf1'].fillna(0, inplace=True)
df['bsmt_fin_sf2'].fillna(0, inplace=True)

# %%
# cross reference bsmt_exposure with basement_qual
df[df['bsmt_exposure'].isna()]['bsmt_qual'].value_counts(0)
# Out:
# NA    69
# Gd     2
# Name: bsmt_qual, dtype: int64

# %%
# fill with NA where 'bsmt_qual' = NA
df.loc[(df.bsmt_exposure.isna()) & (df.bsmt_qual == 'NA'), 'bsmt_exposure'] = 'NA'

# fill remaining with mode
df['bsmt_exposure'].fillna(df.bsmt_exposure.mode()[0], inplace=True)

# %% [markdown]
# ### mas_vnr_type and mas_vnr_area
# - Masonry veneer type
# - Masonry veneer area in square feet

# %%
# replace values with mode and median, respectively
df['mas_vnr_type'].fillna(df.mas_vnr_type.mode()[0], inplace=True)
df['mas_vnr_area'].fillna(df.mas_vnr_area.median(), inplace=True)

# %% [markdown]
# ### electrical

# %%
# view record
df[df['electrical'].isna()]
# Out:
#             pid  gr_liv_area  sale_price  ms_sub_class ms_zoning  \
# 2442  916386080         1394      167500            80        RL
#
#       lot_frontage  lot_area street alley lot_shape land_contour utilities  \
# 2442          73.0      9735   Pave    NA       Reg          Lvl    AllPub
#
#      lot_config land_slope neighborhood condition1 condition2 bldg_type  \
# 2442     Inside        Gtl       Timber       Norm       Norm      1Fam
#
#      house_style  overall_qual  overall_cond  year_built  year_remod_add  \
# 2442        SLvl             5             5        2006            2007
#
#      roof_style roof_matl exterior1st exterior2nd mas_vnr_type  mas_vnr_area  \
# 2442      Gable   CompShg     VinylSd     VinylSd         None           0.0
#
#      exter_qual exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure  \
# 2442         TA         TA      PConc        Gd        TA            No
#
#      bsmt_fin_type1  bsmt_fin_sf1 bsmt_fin_type2  bsmt_fin_sf2  bsmt_unf_sf  \
# 2442            Unf           0.0            Unf           0.0        384.0
#
#       total_bsmt_sf heating heating_qc central_air electrical  1st_flr_sf  \
# 2442          384.0    GasA         Gd           Y        NaN         754
#
#       2nd_flr_sf  low_qual_fin_sf  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 2442         640                0             0.0             0.0          2
#
#       half_bath  bedroom_abv_gr  kitchen_abv_gr kitchen_qual  tot_rms_abv_grd  \
# 2442          1               3               1           Gd                7
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 2442        Typ           0           NA     BuiltIn         2007.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 2442           Fin          2.0        400.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3_ssn_porch  \
# 2442           Y           100              0               0            0
#
#       screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 2442             0          0      NA    NA           NA         0        5
#
#       yr_sold sale_type sale_condition  log_sale_price
# 2442     2008       WD          Normal       12.028739

# %%
# observation looks normal, fill with mode
df['electrical'].fillna(df.electrical.mode()[0], inplace=True)

# %% [markdown]
# ### garage_yr_blt

# %%
# Plot Garage Year Built vs House Year Built
df.plot(x='garage_yr_blt', y='year_built', kind='scatter')
plt.show()

# check correlation
df.garage_yr_blt.corr(df.year_built)
# Out:
# 0.8344432354739171

# %%
# Plot Garage Year Built vs Sale Price
sns.scatterplot(data=df[~df['garage_yr_blt'].isna()], x='year_built', y='sale_price', alpha=0.3)
sns.scatterplot(data=df[~df['garage_yr_blt'].isna()], x='garage_yr_blt', y='sale_price', alpha=0.3)
plt.show()
    
# check correlation
df.garage_yr_blt.corr(df.year_built)
# Out:
# 0.8344432354739171

# %%
# dropping column due to it's strong correlation with House Year Built
df.drop('garage_yr_blt', axis=1, inplace=True)

# %% [markdown]
# # Outlier Handling

# %% [markdown]
# Look at boxplot of sale price

# %%
plt.boxplot(x = df['sale_price'], whis=1.5, vert=False)
plt.show()

# %%
corr_series = df.corr()['sale_price'].sort_values(key=abs, ascending=False)
corr_series
# Out:
# sale_price         1.000000
# log_sale_price     0.950064
# overall_qual       0.791847
# gr_liv_area        0.725780
# total_bsmt_sf      0.655575
# 1st_flr_sf         0.645971
# garage_cars        0.639237
# garage_area        0.635414
# year_built         0.544688
# full_bath          0.535817
# year_remod_add     0.514820
# mas_vnr_area       0.499769
# tot_rms_abv_grd    0.490963
# fireplaces         0.488188
# bsmt_fin_sf1       0.462518
# wood_deck_sf       0.333351
# lot_frontage       0.328093
# open_porch_sf      0.308221
# bsmt_full_bath     0.290896
# half_bath          0.285904
# lot_area           0.275026
# 2nd_flr_sf         0.263428
# pid               -0.226492
# bsmt_unf_sf        0.168111
# bedroom_abv_gr     0.151919
# enclosed_porch    -0.123200
# screen_porch       0.121404
# kitchen_abv_gr    -0.113956
# overall_cond      -0.101110
# ms_sub_class      -0.084576
# bsmt_half_bath    -0.033758
# 3_ssn_porch        0.031272
# pool_area          0.030851
# low_qual_fin_sf   -0.030824
# bsmt_fin_sf2       0.022705
# misc_val          -0.018866
# mo_sold            0.012680
# yr_sold           -0.001239
# Name: sale_price, dtype: float64

# %%
print(corr_series.index.tolist()[2:22])
# Out:
# ['overall_qual', 'gr_liv_area', 'total_bsmt_sf', '1st_flr_sf', 'garage_cars', 'garage_area', 'year_built', 'full_bath', 'year_remod_add', 'mas_vnr_area', 'tot_rms_abv_grd', 'fireplaces', 'bsmt_fin_sf1', 'wood_deck_sf', 'lot_frontage', 'open_porch_sf', 'bsmt_full_bath', 'half_bath', 'lot_area', '2nd_flr_sf']

# %% [markdown]
# Plot Overall Quality vs Log Sale Price

# %%
sns.stripplot(data=df, jitter = 0.3, x='overall_qual', y='sale_price', alpha=0.75, color='skyblue', size=3.5)
plt.xlabel('Overall Quality')
plt.ylabel('Sale Price')
plt.tight_layout()
plt.savefig('overall.png', transparent=True)
plt.show()

# %% [markdown]
# No obvious outliers
#
# Plot Square Feet vs sale Price

# %%
sns.pairplot(df[['sale_price', 'gr_liv_area', 'total_bsmt_sf', 'garage_area', 'year_built'][::-1]], corner = True, kind='reg',\
             diag_kws={'color':'orange'}, plot_kws={'scatter_kws':{'s':5, 'alpha':0.8, 'color':'#EEFE41'}, 'line_kws':{'color':'skyblue'}},\
             height = 1.8, aspect=1)
plt.tight_layout()
plt.savefig('pair.png', transparent=True)
plt.show()

# %%
sns.lmplot(data=df, x = 'gr_liv_area', y='sale_price')
plt.show()

# %% [markdown]
# Drop the obvious outlier

# %%
df.drop(309, inplace=True)

# %%
# replot
plt.figure(figsize=(7,7))
sns.regplot(data=df, x = 'gr_liv_area', y='sale_price', color='salmon', scatter_kws={'s':8})
plt.xlabel('Above Ground Living Area (sqft)')
plt.ylabel('Sale Price ($)')
plt.tight_layout()
plt.savefig('reg_sale_price.png', transparent=True)
plt.show()

# %%
corr_map = round(df[['sale_price', 'overall_qual', 'gr_liv_area', 'total_bsmt_sf', '1st_flr_sf', 'garage_cars', 'garage_area', 'year_built', 'full_bath', 'year_remod_add', 'mas_vnr_area', 'tot_rms_abv_grd', 'fireplaces', 'bsmt_fin_sf1', 'wood_deck_sf', 'lot_frontage', 'open_porch_sf', 'bsmt_full_bath', 'half_bath', 'lot_area', '2nd_flr_sf'][::-1]].corr().abs(),2)

mask = np.triu(np.ones_like(corr_map, dtype=bool))
plt.figure(figsize=(13,9))
sns.heatmap(corr_map, mask=mask, annot=True, square=True )
plt.tight_layout()
plt.savefig('corr_map.png', transparent=True)
plt.show()

# %%
df.reset_index(inplace=True, drop=True)
df
# Out:
#             pid  gr_liv_area  sale_price  ms_sub_class ms_zoning  \
# 0     909176150          856      126000            30        RL
# 1     905476230         1049      139500           120        RL
# 2     911128020         1001      124900            30   C (all)
# 3     535377150         1039      114000            70        RL
# 4     534177230         1665      227000            60        RL
# ...         ...          ...         ...           ...       ...
# 2573  903205040          952      121000            30        RL
# 2574  905402060         1733      139600            20        RL
# 2575  909275030         2002      145000            90        RH
# 2576  907192040         1842      217500            60        RL
# 2577  906223180         1911      215000            60        RL
#
#       lot_frontage  lot_area street alley lot_shape land_contour utilities  \
# 0             80.0      7890   Pave    NA       Reg          Lvl    AllPub
# 1             42.0      4235   Pave    NA       Reg          Lvl    AllPub
# 2             60.0      6060   Pave    NA       Reg          Lvl    AllPub
# 3             80.0      8146   Pave    NA       Reg          Lvl    AllPub
# 4             70.0      8400   Pave    NA       Reg          Lvl    AllPub
# ...            ...       ...    ...   ...       ...          ...       ...
# 2573          65.0      8854   Pave    NA       Reg          Lvl    AllPub
# 2574          49.0     13680   Pave    NA       IR1          Lvl    AllPub
# 2575          82.0      6270   Pave    NA       Reg          HLS    AllPub
# 2576          65.0      8826   Pave    NA       Reg          Lvl    AllPub
# 2577          80.0      9554   Pave    NA       IR1          Lvl    AllPub
#
#      lot_config land_slope neighborhood condition1 condition2 bldg_type  \
# 0        Corner        Gtl        SWISU       Norm       Norm      1Fam
# 1        Inside        Gtl      Edwards       Norm       Norm    TwnhsE
# 2        Inside        Gtl       IDOTRR       Norm       Norm      1Fam
# 3        Corner        Gtl      OldTown       Norm       Norm      1Fam
# 4        Inside        Gtl       NWAmes       Norm       Norm      1Fam
# ...         ...        ...          ...        ...        ...       ...
# 2573     Inside        Gtl      BrkSide       Norm       Norm      1Fam
# 2574    CulDSac        Gtl      Edwards       Norm       Norm      1Fam
# 2575     Inside        Gtl      Crawfor       Norm       Norm    Duplex
# 2576     Inside        Gtl      CollgCr       Norm       Norm      1Fam
# 2577     Inside        Gtl      SawyerW       Norm       Norm      1Fam
#
#      house_style  overall_qual  overall_cond  year_built  year_remod_add  \
# 0         1Story             6             6        1939            1950
# 1         1Story             5             5        1984            1984
# 2         1Story             5             9        1930            2007
# 3         2Story             4             8        1900            2003
# 4         2Story             8             6        2001            2001
# ...          ...           ...           ...         ...             ...
# 2573      1.5Unf             6             6        1916            1950
# 2574      1Story             3             5        1955            1955
# 2575      2Story             5             6        1949            1950
# 2576      2Story             7             5        2000            2000
# 2577      2Story             8             5        1993            1994
#
#      roof_style roof_matl exterior1st exterior2nd mas_vnr_type  mas_vnr_area  \
# 0         Gable   CompShg     Wd Sdng     Wd Sdng         None           0.0
# 1         Gable   CompShg     HdBoard     HdBoard      BrkFace         149.0
# 2           Hip   CompShg     MetalSd     MetalSd         None           0.0
# 3         Gable   CompShg     MetalSd     MetalSd         None           0.0
# 4         Gable   CompShg     VinylSd     VinylSd         None           0.0
# ...         ...       ...         ...         ...          ...           ...
# 2573      Gable   CompShg     Wd Sdng     Wd Sdng         None           0.0
# 2574        Hip   CompShg     BrkFace     Wd Sdng         None           0.0
# 2575      Gable   CompShg     MetalSd     MetalSd         None           0.0
# 2576      Gable   CompShg     VinylSd     VinylSd      BrkFace         144.0
# 2577      Gable   CompShg     VinylSd     VinylSd      BrkFace         125.0
#
#      exter_qual exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure  \
# 0            TA         TA     CBlock        TA        TA            No
# 1            Gd         TA     CBlock        Gd        TA            Mn
# 2            Gd         TA     BrkTil        TA        TA            No
# 3            Gd         Gd     BrkTil        Fa        TA            No
# 4            Gd         TA      PConc        Gd        TA            No
# ...         ...        ...        ...       ...       ...           ...
# 2573         TA         TA     BrkTil        TA        TA            No
# 2574         TA         TA       Slab        NA        NA            NA
# 2575         TA         TA     CBlock        TA        TA            No
# 2576         Gd         TA      PConc        Gd        TA            No
# 2577         Gd         TA      PConc        Gd        TA            No
#
#      bsmt_fin_type1  bsmt_fin_sf1 bsmt_fin_type2  bsmt_fin_sf2  bsmt_unf_sf  \
# 0               Rec         238.0            Unf           0.0        618.0
# 1               GLQ         552.0            ALQ         393.0        104.0
# 2               ALQ         737.0            Unf           0.0        100.0
# 3               Unf           0.0            Unf           0.0        405.0
# 4               GLQ         643.0            Unf           0.0        167.0
# ...             ...           ...            ...           ...          ...
# 2573            Unf           0.0            Unf           0.0        952.0
# 2574             NA           0.0             NA           0.0          0.0
# 2575            BLQ         284.0            Unf           0.0        717.0
# 2576            GLQ         841.0            Unf           0.0        144.0
# 2577            GLQ         380.0            Unf           0.0        397.0
#
#       total_bsmt_sf heating heating_qc central_air electrical  1st_flr_sf  \
# 0             856.0    GasA         TA           Y      SBrkr         856
# 1            1049.0    GasA         TA           Y      SBrkr        1049
# 2             837.0    GasA         Ex           Y      SBrkr        1001
# 3             405.0    GasA         Gd           Y      SBrkr         717
# 4             810.0    GasA         Ex           Y      SBrkr         810
# ...             ...     ...        ...         ...        ...         ...
# 2573          952.0    Grav         Fa           N      FuseF         952
# 2574            0.0    GasA         Ex           Y      FuseA        1733
# 2575         1001.0    GasA         TA           N      FuseA        1001
# 2576          985.0    GasA         Ex           Y      SBrkr         985
# 2577          777.0    GasA         Ex           Y      SBrkr        1065
#
#       2nd_flr_sf  low_qual_fin_sf  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 0              0                0             1.0             0.0          1
# 1              0                0             1.0             0.0          2
# 2              0                0             0.0             0.0          1
# 3            322                0             0.0             0.0          1
# 4            855                0             1.0             0.0          2
# ...          ...              ...             ...             ...        ...
# 2573           0                0             0.0             0.0          1
# 2574           0                0             0.0             0.0          2
# 2575        1001                0             0.0             0.0          2
# 2576         857                0             1.0             0.0          2
# 2577         846                0             0.0             0.0          2
#
#       half_bath  bedroom_abv_gr  kitchen_abv_gr kitchen_qual  tot_rms_abv_grd  \
# 0             0               2               1           TA                4
# 1             0               2               1           Gd                5
# 2             0               2               1           Gd                5
# 3             0               2               1           TA                6
# 4             1               3               1           Gd                6
# ...         ...             ...             ...          ...              ...
# 2573          0               2               1           Fa                4
# 2574          0               4               1           TA                8
# 2575          0               4               2           TA                8
# 2576          1               3               1           Gd                7
# 2577          1               3               1           Gd                8
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 0           Typ           1           Gd      Detchd         1939.0
# 1           Typ           0           NA      Attchd         1984.0
# 2           Typ           0           NA      Detchd         1930.0
# 3           Typ           0           NA      Detchd         1940.0
# 4           Typ           0           NA      Attchd         2001.0
# ...         ...         ...          ...         ...            ...
# 2573        Typ           1           Gd      Detchd         1916.0
# 2574       Min2           1           Gd      Attchd         1955.0
# 2575        Typ           0           NA      2Types         1949.0
# 2576        Typ           1           TA      Attchd         2000.0
# 2577        Typ           1           TA      Attchd         1993.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 0              Unf          2.0        399.0          TA          TA
# 1              Fin          1.0        266.0          TA          TA
# 2              Unf          1.0        216.0          TA          Po
# 3              Unf          1.0        281.0          TA          TA
# 4              Fin          2.0        528.0          TA          TA
# ...            ...          ...          ...         ...         ...
# 2573           Unf          1.0        192.0          Fa          Po
# 2574           Unf          2.0        452.0          TA          TA
# 2575           Unf          3.0        871.0          TA          TA
# 2576           Fin          2.0        486.0          TA          TA
# 2577           RFn          2.0        471.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3_ssn_porch  \
# 0              Y             0              0               0            0
# 1              Y             0            105               0            0
# 2              N           154              0              42           86
# 3              N             0              0             168            0
# 4              Y             0             45               0            0
# ...          ...           ...            ...             ...          ...
# 2573           P             0             98               0            0
# 2574           Y             0              0               0            0
# 2575           Y             0              0               0            0
# 2576           Y           193             96               0            0
# 2577           Y           182             81               0            0
#
#       screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 0              166          0      NA    NA           NA         0        3
# 1                0          0      NA    NA           NA         0        2
# 2                0          0      NA    NA           NA         0       11
# 3              111          0      NA    NA           NA         0        5
# 4                0          0      NA    NA           NA         0       11
# ...            ...        ...     ...   ...          ...       ...      ...
# 2573            40          0      NA    NA           NA         0        5
# 2574             0          0      NA    NA           NA         0        6
# 2575             0          0      NA    NA           NA         0        8
# 2576             0          0      NA    NA           NA         0        7
# 2577             0          0      NA    NA           NA         0        9
#
#       yr_sold sale_type sale_condition  log_sale_price
# 0        2010       WD          Normal       11.744037
# 1        2009       WD          Normal       11.845820
# 2        2007       WD          Normal       11.735269
# 3        2009       WD          Normal       11.643954
# 4        2009       WD          Normal       12.332705
# ...       ...       ...            ...             ...
# 2573     2009       WD          Normal       11.703546
# 2574     2009       WD          Normal       11.846536
# 2575     2007       WD          Normal       11.884489
# 2576     2007       WD          Normal       12.289954
# 2577     2006       WD          Normal       12.278393
#
# [2578 rows x 82 columns]

# %%
df.to_csv('../data/L1/ames_house_price_cleaned.csv', index=False)
